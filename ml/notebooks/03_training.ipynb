# %% [markdown]
# # 03. Model Training & Comparison
#
# Train and compare Logistic Regression, Random Forest, and XGBoost with hyperparameter tuning.

# %%
import os, sys, json
sys.path.insert(0, os.path.abspath('..'))
from src.train import train_and_compare_models

best_candidate, pipeline, meta_data = train_and_compare_models()
print(f"Best Selected Model: {meta_data['best_model_name']}")

# %% [markdown]
# ## Comparison Summary

# %%
import pandas as pd
comp_df = pd.DataFrame(meta_data['all_models_comparison'])
comp_df
